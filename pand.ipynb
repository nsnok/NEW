# %%
import numpy as np
import pandas as pd

# %%
s=pd.Series([1,2,np.nan])
s
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
s[0]
# Out:
# 1.0

# %%
s.sum()
# Out:
# 3.0

# %%
df=pd.DataFrame({'A':[1,2],'B':[3,4]})
df
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
df=pd.DataFrame(np.random.randn(6,4), index=pd.date_range('20210209',periods=6))
df
# Out:
#                    0         1         2         3
# 2021-02-09  0.177386  0.616650  1.066747  0.032944
# 2021-02-10  0.626073 -0.131885 -0.454517  0.157542
# 2021-02-11  0.789420  0.321005 -2.029064 -0.386336
# 2021-02-12  0.878810 -0.849861 -0.882638 -0.559477
# 2021-02-13 -0.815347 -0.978974  0.874973  0.979554
# 2021-02-14 -1.895414  0.031329 -0.303577  2.153762

# %%
df=pd.DataFrame(np.random.randn(6,4), index=pd.date_range('20210209',periods=6),columns=['A','B','C','D'])
df
# Out:
#                    A         B         C         D
# 2021-02-09  0.599434 -0.068266 -0.173935  0.443951
# 2021-02-10 -0.201775 -2.392348 -0.760791 -0.152800
# 2021-02-11  1.259959  0.737373  0.002564 -0.411978
# 2021-02-12  0.395167 -0.969939 -0.006346  0.277351
# 2021-02-13 -1.386286 -0.340798 -0.777571 -0.299013
# 2021-02-14 -1.120621  0.627955 -0.510467 -0.690136

# %%
r=df.T
print(r)
# Out:
#    2021-02-09  2021-02-10  2021-02-11  2021-02-12  2021-02-13  2021-02-14
# A    0.599434   -0.201775    1.259959    0.395167   -1.386286   -1.120621
# B   -0.068266   -2.392348    0.737373   -0.969939   -0.340798    0.627955
# C   -0.173935   -0.760791    0.002564   -0.006346   -0.777571   -0.510467
# D    0.443951   -0.152800   -0.411978    0.277351   -0.299013   -0.690136

# %%
df.loc[:,['A','B']]
df
# Out:
#                    A         B         C         D
# 2021-02-09  0.599434 -0.068266 -0.173935  0.443951
# 2021-02-10 -0.201775 -2.392348 -0.760791 -0.152800
# 2021-02-11  1.259959  0.737373  0.002564 -0.411978
# 2021-02-12  0.395167 -0.969939 -0.006346  0.277351
# 2021-02-13 -1.386286 -0.340798 -0.777571 -0.299013
# 2021-02-14 -1.120621  0.627955 -0.510467 -0.690136

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2021-02-09  0.599434       NaN       NaN  0.443951
# 2021-02-10       NaN       NaN       NaN       NaN
# 2021-02-11  1.259959  0.737373  0.002564       NaN
# 2021-02-12  0.395167       NaN       NaN  0.277351
# 2021-02-13       NaN       NaN       NaN       NaN
# 2021-02-14       NaN  0.627955       NaN       NaN

# %%
df2=df.copy()
df2['E']=['one','one','tow','three','four','five']
df2
# Out:
#                    A         B         C         D      E
# 2021-02-09  0.599434 -0.068266 -0.173935  0.443951    one
# 2021-02-10 -0.201775 -2.392348 -0.760791 -0.152800    one
# 2021-02-11  1.259959  0.737373  0.002564 -0.411978    tow
# 2021-02-12  0.395167 -0.969939 -0.006346  0.277351  three
# 2021-02-13 -1.386286 -0.340798 -0.777571 -0.299013   four
# 2021-02-14 -1.120621  0.627955 -0.510467 -0.690136   five

# %%
df2[df2['E'].isin(['one'])]
# Out:
#                    A         B         C         D    E
# 2021-02-09  0.599434 -0.068266 -0.173935  0.443951  one
# 2021-02-10 -0.201775 -2.392348 -0.760791 -0.152800  one

# %%
s=pd.Series([1,2,3,4,5,6],index=pd.date_range('20200209',periods=6))
s
# Out:
# 2020-02-09    1
# 2020-02-10    2
# 2020-02-11    3
# 2020-02-12    4
# 2020-02-13    5
# 2020-02-14    6
# Freq: D, dtype: int64

# %%
df['E']=s
df
# Out:
#                    A         B         C         D   E
# 2021-02-09  0.599434 -0.068266 -0.173935  0.443951 NaN
# 2021-02-10 -0.201775 -2.392348 -0.760791 -0.152800 NaN
# 2021-02-11  1.259959  0.737373  0.002564 -0.411978 NaN
# 2021-02-12  0.395167 -0.969939 -0.006346  0.277351 NaN
# 2021-02-13 -1.386286 -0.340798 -0.777571 -0.299013 NaN
# 2021-02-14 -1.120621  0.627955 -0.510467 -0.690136 NaN

# %%
df.shift(1)
# Out:
#                    A         B         C         D   E
# 2021-02-09       NaN       NaN       NaN       NaN NaN
# 2021-02-10  0.599434 -0.068266 -0.173935  0.443951 NaN
# 2021-02-11 -0.201775 -2.392348 -0.760791 -0.152800 NaN
# 2021-02-12  1.259959  0.737373  0.002564 -0.411978 NaN
# 2021-02-13  0.395167 -0.969939 -0.006346  0.277351 NaN
# 2021-02-14 -1.386286 -0.340798 -0.777571 -0.299013 NaN

# %%
import pandas_datareader
ds=pandas_datareader.data.DataReader('AAPL','yahoo','2021-01-01')
ds
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-12-31  134.740005  131.720001  134.080002  132.690002   98990400.0
# 2021-01-04  133.610001  126.760002  133.520004  129.410004  143301900.0
# 2021-01-05  131.740005  128.429993  128.889999  131.009995   97664900.0
# 2021-01-06  131.050003  126.379997  127.720001  126.599998  155088000.0
# 2021-01-07  131.630005  127.860001  128.360001  130.919998  109578200.0
# 2021-01-08  132.630005  130.229996  132.429993  132.050003  104965400.0
# 2021-01-11  130.169998  128.500000  129.190002  128.979996  100620900.0
# 2021-01-12  129.690002  126.860001  128.500000  128.800003   91951100.0
# 2021-01-13  131.449997  128.490005  128.759995  130.889999   88636800.0
# 2021-01-14  131.000000  128.759995  130.800003  128.910004   90221800.0
# 2021-01-15  130.220001  127.000000  128.779999  127.139999  111235300.0
# 2021-01-19  128.710007  126.940002  127.779999  127.830002   90757300.0
# ...

# %%
ds.head(1)
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-12-31  134.740005  131.720001  134.080002  132.690002  98990400.0
#
#             Adj Close
# Date
# 2020-12-31  132.49202

# %%
import matplotlib
